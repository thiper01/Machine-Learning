# %%
lista = []
lista.append("Rudney")
lista.append("Fefe")
lista.append("Biels")
lista.append("Rodrigo")
lista.append("Rudney")

msg = (str(lista.count("Rudney"))+ " elementos encontrados")

if "Rudney" in lista:
  positions = []
  Index = -1
  for i in range(lista.count("Rudney")):
    Index = lista.index("Rudney", Index + 1)
    print(Index)
    positions.append(Index)
  msg += "nas posicoes: "+ str(positions)
print(msg)
# Out:
# 0
# 4
# 2 elementos encontradosnas posicoes: [0, 4]

# %%
import pandas as pd

# %%
df = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/robustbase/Animals2.csv")
df.head()


#print(df['brain'].where(df['body'] < 50))
# Out:
#         Unnamed: 0    body  brain
# 0  Mountain beaver    1.35    8.1
# 1              Cow  465.00  423.0
# 2        Grey wolf   36.33  119.5
# 3             Goat   27.66  115.0
# 4       Guinea pig    1.04    5.5
